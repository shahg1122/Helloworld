# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Salman Bukhari**
# ###### Self_learner about Data Science

# %% [markdown]
# *I am interested in Data Science because of its innovational techniques that can help you prosper in any business technically*

# %% [markdown]
# ##### I am righting a simple code which prints each element of a list.

# %%
List_1 = ['apple', 'oranges', 'mangoes']
for i in List_1:
    print(i)
# Out:
# apple
# oranges
# mangoes

# %% [markdown]
# ~~Cutting something in between~~
#
# ```python
# i = "Python syntax highlighting"
# print i
# ```
# + One
# + Two
# - Three
# * Four
